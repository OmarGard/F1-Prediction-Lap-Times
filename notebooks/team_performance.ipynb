# %%
import fastf1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta

# Get the base directory path
fastf1.Cache.enable_cache('../data')  # Cache in /data

# %%
from fastf1.ergast import Ergast
ergast = Ergast()

standings = ergast.get_constructor_standings(season=2025, round=12)

# %%
standings.content[0]
# Out:
#    position positionText  points  wins constructorId  \
# 0         1            1   460.0     9       mclaren
# 1         2            2   222.0     0       ferrari
# 2         3            3   210.0     1      mercedes
# 3         4            4   172.0     2      red_bull
# 4         5            5    59.0     0      williams
# 5         6            6    41.0     0        sauber
# 6         7            7    36.0     0            rb
# 7         8            8    36.0     0  aston_martin
# 8         9            9    29.0     0          haas
# 9        10           10    19.0     0        alpine
#
#                                       constructorUrl constructorName  \
# 0               http://en.wikipedia.org/wiki/McLaren         McLaren
# 1      http://en.wikipedia.org/wiki/Scuderia_Ferrari         Ferrari
# 2  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...        Mercedes
# 3       http://en.wikipedia.org/wiki/Red_Bull_Racing        Red Bull
# ...

# %%
# save the standings to a CSV file
standings_df = pd.DataFrame(standings.content[0])
standings_df.to_csv('../data/standings/constructor_standings_2025_Round_12_Great_Britain.csv', index=False)
